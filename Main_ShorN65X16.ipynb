# %%
from ShorAlgorithm import ShorN65X16
# Out:
# 0
# 14

# %%
from qiskit import IBMQ

provider = IBMQ.load_account()
my_provider = IBMQ.get_provider(hub='ibm-q', group='open', project='main')
backends = my_provider.backends()

for backend in backends:
    print(backend) # only available for 7-qubit device
# Out:
# ibmqfactory.load_account:WARNING:2023-04-04 14:18:28,372: Credentials are already in use. The existing account in the session will be replaced.
# ibmq_qasm_simulator
# ibmq_lima
# ibmq_belem
# ibmq_quito
# simulator_statevector
# simulator_mps
# simulator_extended_stabilizer
# simulator_stabilizer
# ibmq_jakarta
# ibmq_manila
# ibm_lagos
# ibm_nairobi
# ibm_perth
# ibm_oslo

# %%
ShorN65X16(shots=1000, backend_name="ibmq_qasm_simulator", IsTwirl=False).SimulationQC()
# Out:
# ibmqfactory.load_account:WARNING:2023-04-04 14:18:32,049: Credentials are already in use. The existing account in the session will be replaced.
# 0
# 14
# ...
# Name of Backend : ibmq_qasm_simulator
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 31
# Simulation Result (counts) : {'000': 356, '001': 23, '010': 60, '011': 225, '100': 21, '101': 237, '110': 65, '111': 13}
# ...

# %%
ShorN65X16(shots=1000, backend_name="ibmq_qasm_simulator", IsTwirl=True).SimulationQC()
# Out:
# ibmqfactory.load_account:WARNING:2023-04-04 14:18:44,308: Credentials are already in use. The existing account in the session will be replaced.
# 0
# 14
# ...
# Unitary Index : 1
# Name of Backend : ibmq_qasm_simulator
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 31
# Simulation Result (counts) : {'000': 339, '001': 16, '010': 63, '011': 231, '100': 37, '101': 230, '110': 72, '111': 12}
# ...
#
# ...
# Unitary Index : 5
# Name of Backend : ibmq_qasm_simulator
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 32
# Simulation Result (counts) : {'000': 331, '001': 18, '010': 61, '011': 260, '100': 24, '101': 231, '110': 60, '111': 15}
# ...
#
# ...
# Unitary Index : 9
# Name of Backend : ibmq_qasm_simulator
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 32
# Simulation Result (counts) : {'000': 345, '001': 20, '010': 61, '011': 247, '100': 35, '101': 226, '110': 49, '111': 17}
# ...

# %%
ShorN65X16(shots=1000, backend_name="ibm_perth", IsTwirl=False).SimulationQC()
# Out:
# ibmqfactory.load_account:WARNING:2023-04-04 14:19:35,830: Credentials are already in use. The existing account in the session will be replaced.
# 12
# 14
# ...
# Name of Backend : ibm_perth
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 95
# Simulation Result (counts) : {'000': 141, '001': 103, '010': 105, '011': 72, '100': 126, '101': 151, '110': 140, '111': 162}
# ...

# %%
ShorN65X16(shots=1000, backend_name="ibm_perth", IsTwirl=True).SimulationQC()
# Out:
# ibmqfactory.load_account:WARNING:2023-04-04 18:38:57,740: Credentials are already in use. The existing account in the session will be replaced.
# 12
# 14
# ...
# Unitary Index : 1
# Name of Backend : ibm_perth
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 88
# Simulation Result (counts) : {'000': 122, '001': 134, '010': 103, '011': 132, '100': 105, '101': 150, '110': 116, '111': 138}
# ...
#
# ...
# Unitary Index : 5
# Name of Backend : ibm_perth
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 91
# Simulation Result (counts) : {'000': 141, '001': 130, '010': 123, '011': 124, '100': 104, '101': 124, '110': 148, '111': 106}
# ...
#
# ...
# Unitary Index : 9
# Name of Backend : ibm_perth
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 103
# Simulation Result (counts) : {'000': 183, '001': 125, '010': 116, '011': 132, '100': 113, '101': 90, '110': 140, '111': 101}
# ...

# %%
ShorN65X16(shots=1000, backend_name="ibm_lagos", IsTwirl=False).SimulationQC()
# Out:
# ibmqfactory.load_account:WARNING:2023-04-04 18:54:58,056: Credentials are already in use. The existing account in the session will be replaced.
# 10
# 14
# ...
# Name of Backend : ibm_lagos
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 89
# Simulation Result (counts) : {'000': 138, '001': 89, '010': 130, '011': 139, '100': 133, '101': 145, '110': 140, '111': 86}
# ...

# %%
ShorN65X16(shots=1000, backend_name="ibm_lagos", IsTwirl=True).SimulationQC()
# Out:
# ibmqfactory.load_account:WARNING:2023-04-05 00:37:05,147: Credentials are already in use. The existing account in the session will be replaced.
# 10
# 14
# ...
# Unitary Index : 1
# Name of Backend : ibm_lagos
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 100
# Simulation Result (counts) : {'000': 120, '001': 108, '010': 110, '011': 147, '100': 93, '101': 157, '110': 140, '111': 125}
# ...
#
# ...
# Unitary Index : 5
# Name of Backend : ibm_lagos
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 103
# Simulation Result (counts) : {'000': 132, '001': 109, '010': 112, '011': 133, '100': 116, '101': 161, '110': 117, '111': 120}
# ...
#
# ...
# Unitary Index : 9
# Name of Backend : ibm_lagos
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 106
# Simulation Result (counts) : {'000': 141, '001': 91, '010': 122, '011': 141, '100': 101, '101': 158, '110': 123, '111': 123}
# ...

# %%
ShorN65X16(shots=1000, backend_name="ibm_nairobi", IsTwirl=False).SimulationQC()
# Out:
# ibmqfactory.load_account:WARNING:2023-04-05 01:15:01,962: Credentials are already in use. The existing account in the session will be replaced.
# 11
# 14
# ...
# Name of Backend : ibm_nairobi
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 102
# Simulation Result (counts) : {'000': 168, '001': 113, '010': 94, '011': 132, '100': 114, '101': 165, '110': 104, '111': 110}
# ...

# %%
ShorN65X16(shots=1000, backend_name="ibm_nairobi", IsTwirl=True).SimulationQC()
# Out:
# ibmqfactory.load_account:WARNING:2023-04-05 06:46:18,555: Credentials are already in use. The existing account in the session will be replaced.
# 11
# 14
# ...
# Unitary Index : 1
# Name of Backend : ibm_nairobi
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 96
# Simulation Result (counts) : {'000': 90, '001': 125, '010': 137, '011': 143, '100': 135, '101': 102, '110': 167, '111': 101}
# ...
#
# ...
# Unitary Index : 5
# Name of Backend : ibm_nairobi
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 111
# Simulation Result (counts) : {'000': 139, '001': 128, '010': 113, '011': 105, '100': 130, '101': 157, '110': 120, '111': 108}
# ...
#
# ...
# Unitary Index : 9
# Name of Backend : ibm_nairobi
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 94
# Simulation Result (counts) : {'000': 120, '001': 157, '010': 102, '011': 121, '100': 166, '101': 111, '110': 105, '111': 118}
# ...

# %%
ShorN65X16(shots=1000, backend_name="ibm_oslo", IsTwirl=False).SimulationQC()
# Out:
# ibmqfactory.load_account:WARNING:2023-04-06 06:10:20,635: Credentials are already in use. The existing account in the session will be replaced.
# 13
# 14
# ...
# Name of Backend : ibm_oslo
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 89
# Simulation Result (counts) : {'000': 186, '001': 97, '010': 118, '011': 86, '100': 123, '101': 150, '110': 124, '111': 116}
# ...

# %%
ShorN65X16(shots=1000, backend_name="ibm_oslo", IsTwirl=True).SimulationQC()
# Out:
# ibmqfactory.load_account:WARNING:2023-04-06 06:14:07,528: Credentials are already in use. The existing account in the session will be replaced.
# 13
# 14
# ...
# Unitary Index : 1
# Name of Backend : ibm_oslo
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 102
# Simulation Result (counts) : {'000': 122, '001': 142, '010': 93, '011': 115, '100': 143, '101': 118, '110': 128, '111': 139}
# ...
#
# ...
# Unitary Index : 5
# Name of Backend : ibm_oslo
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 104
# Simulation Result (counts) : {'000': 139, '001': 131, '010': 99, '011': 106, '100': 121, '101': 188, '110': 94, '111': 122}
# ...
#
# ...
# Unitary Index : 9
# Name of Backend : ibm_oslo
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 101
# Simulation Result (counts) : {'000': 178, '001': 140, '010': 111, '011': 124, '100': 131, '101': 89, '110': 114, '111': 113}
# ...

# %%
ShorN65X16(shots=1000, backend_name="ibmq_jakarta", IsTwirl=False).SimulationQC()
# Out:
# ibmqfactory.load_account:WARNING:2023-04-06 06:22:19,138: Credentials are already in use. The existing account in the session will be replaced.
# 8
# 14
# ...
# Name of Backend : ibmq_jakarta
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 96
# Simulation Result (counts) : {'000': 155, '001': 121, '010': 155, '011': 152, '100': 106, '101': 98, '110': 128, '111': 85}
# ...

# %%
ShorN65X16(shots=1000, backend_name="ibmq_jakarta", IsTwirl=True).SimulationQC()
# Out:
# ibmqfactory.load_account:WARNING:2023-04-06 14:32:31,424: Credentials are already in use. The existing account in the session will be replaced.
# 8
# 14
# ...
# Unitary Index : 1
# Name of Backend : ibmq_jakarta
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 100
# Simulation Result (counts) : {'000': 181, '001': 90, '010': 170, '011': 133, '100': 85, '101': 118, '110': 107, '111': 116}
# ...
#
# ...
# Unitary Index : 5
# Name of Backend : ibmq_jakarta
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 98
# Simulation Result (counts) : {'000': 136, '001': 135, '010': 116, '011': 122, '100': 97, '101': 125, '110': 127, '111': 142}
# ...
#
# ...
# Unitary Index : 9
# Name of Backend : ibmq_jakarta
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 97
# Simulation Result (counts) : {'000': 136, '001': 146, '010': 134, '011': 102, '100': 102, '101': 126, '110': 95, '111': 159}
# ...
