# %%
from ShorAlgorithm import ShorN35X16
# Out:
# 0
# 14

# %%
from qiskit import IBMQ

provider = IBMQ.load_account()
my_provider = IBMQ.get_provider(hub='ibm-q', group='open', project='main')
backends = my_provider.backends()

for backend in backends:
    print(backend) # only available for 7-qubit device
# Out:
# ibmqfactory.load_account:WARNING:2023-04-04 14:16:44,704: Credentials are already in use. The existing account in the session will be replaced.
# ibmq_qasm_simulator
# ibmq_lima
# ibmq_belem
# ibmq_quito
# simulator_statevector
# simulator_mps
# simulator_extended_stabilizer
# simulator_stabilizer
# ibmq_jakarta
# ibmq_manila
# ibm_lagos
# ibm_nairobi
# ibm_perth
# ibm_oslo

# %%
ShorN35X16(shots=1000, backend_name="ibmq_qasm_simulator", IsTwirl=False).SimulationQC()
# Out:
# ibmqfactory.load_account:WARNING:2023-04-04 14:16:48,925: Credentials are already in use. The existing account in the session will be replaced.
# 0
# 14
# ==================================================
# Name of Backend : ibmq_qasm_simulator
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 31
# Simulation Result (counts) : {'000': 341, '001': 19, '010': 53, '011': 231, '100': 32, '101': 232, '110': 74, '111': 18}
# ==================================================

# %%
ShorN35X16(shots=1000, backend_name="ibmq_qasm_simulator", IsTwirl=True).SimulationQC()
# Out:
# ibmqfactory.load_account:WARNING:2023-04-04 14:17:00,021: Credentials are already in use. The existing account in the session will be replaced.
# 0
# 14
# ==================================================
# Unitary Index : 1
# Name of Backend : ibmq_qasm_simulator
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 31
# Simulation Result (counts) : {'000': 368, '001': 17, '010': 60, '011': 217, '100': 31, '101': 247, '110': 51, '111': 9}
# ==================================================
#
# ==================================================
# Unitary Index : 5
# Name of Backend : ibmq_qasm_simulator
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 32
# Simulation Result (counts) : {'000': 354, '001': 11, '010': 53, '011': 237, '100': 29, '101': 221, '110': 76, '111': 19}
# ==================================================
#
# ==================================================
# Unitary Index : 9
# Name of Backend : ibmq_qasm_simulator
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 32
# Simulation Result (counts) : {'000': 366, '001': 15, '010': 69, '011': 235, '100': 27, '101': 219, '110': 54, '111': 15}
# ==================================================

# %%
ShorN35X16(shots=1000, backend_name="ibm_perth", IsTwirl=False).SimulationQC()
# Out:
# ibmqfactory.load_account:WARNING:2023-04-04 14:17:34,331: Credentials are already in use. The existing account in the session will be replaced.
# 12
# 14
# ==================================================
# Name of Backend : ibm_perth
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 103
# Simulation Result (counts) : {'000': 152, '001': 117, '010': 99, '011': 103, '100': 110, '101': 114, '110': 107, '111': 198}
# ==================================================

# %%
ShorN35X16(shots=1000, backend_name="ibm_perth", IsTwirl=True).SimulationQC()
# Out:
# ibmqfactory.load_account:WARNING:2023-04-04 18:38:17,825: Credentials are already in use. The existing account in the session will be replaced.
# 12
# 14
# ==================================================
# Unitary Index : 1
# Name of Backend : ibm_perth
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 108
# Simulation Result (counts) : {'000': 113, '001': 138, '010': 143, '011': 117, '100': 157, '101': 120, '110': 113, '111': 99}
# ==================================================
#
# ==================================================
# Unitary Index : 5
# Name of Backend : ibm_perth
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 99
# Simulation Result (counts) : {'000': 136, '001': 119, '010': 117, '011': 108, '100': 111, '101': 129, '110': 135, '111': 145}
# ==================================================
#
# ==================================================
# Unitary Index : 9
# Name of Backend : ibm_perth
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 100
# Simulation Result (counts) : {'000': 141, '001': 141, '010': 136, '011': 144, '100': 114, '101': 108, '110': 101, '111': 115}
# ==================================================

# %%
ShorN35X16(shots=1000, backend_name="ibm_lagos", IsTwirl=False).SimulationQC()
# Out:
# ibmqfactory.load_account:WARNING:2023-04-04 18:54:16,910: Credentials are already in use. The existing account in the session will be replaced.
# 10
# 14
# ==================================================
# Name of Backend : ibm_lagos
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 88
# Simulation Result (counts) : {'000': 121, '001': 139, '010': 105, '011': 169, '100': 116, '101': 115, '110': 132, '111': 103}
# ==================================================

# %%
ShorN35X16(shots=1000, backend_name="ibm_lagos", IsTwirl=True).SimulationQC()
# Out:
# ibmqfactory.load_account:WARNING:2023-04-05 00:37:05,686: Credentials are already in use. The existing account in the session will be replaced.
# 10
# 14
# ==================================================
# Unitary Index : 1
# Name of Backend : ibm_lagos
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 103
# Simulation Result (counts) : {'000': 133, '001': 98, '010': 125, '011': 161, '100': 105, '101': 126, '110': 126, '111': 126}
# ==================================================
#
# ==================================================
# Unitary Index : 5
# Name of Backend : ibm_lagos
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 91
# Simulation Result (counts) : {'000': 138, '001': 126, '010': 100, '011': 168, '100': 124, '101': 107, '110': 123, '111': 114}
# ==================================================
#
# ==================================================
# Unitary Index : 9
# Name of Backend : ibm_lagos
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 89
# Simulation Result (counts) : {'000': 111, '001': 103, '010': 97, '011': 154, '100': 144, '101': 137, '110': 145, '111': 109}
# ==================================================

# %%
ShorN35X16(shots=1000, backend_name="ibm_nairobi", IsTwirl=False).SimulationQC()
# Out:
# ibmqfactory.load_account:WARNING:2023-04-05 01:15:04,567: Credentials are already in use. The existing account in the session will be replaced.
# 11
# 14
# ==================================================
# Name of Backend : ibm_nairobi
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 101
# Simulation Result (counts) : {'000': 125, '001': 117, '010': 129, '011': 187, '100': 123, '101': 101, '110': 113, '111': 105}
# ==================================================

# %%
ShorN35X16(shots=1000, backend_name="ibm_nairobi", IsTwirl=True).SimulationQC()
# Out:
# ibmqfactory.load_account:WARNING:2023-04-05 06:46:29,284: Credentials are already in use. The existing account in the session will be replaced.
# 11
# 14
# ==================================================
# Unitary Index : 1
# Name of Backend : ibm_nairobi
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 105
# Simulation Result (counts) : {'000': 169, '001': 95, '010': 97, '011': 160, '100': 109, '101': 148, '110': 103, '111': 119}
# ==================================================
#
# ==================================================
# Unitary Index : 5
# Name of Backend : ibm_nairobi
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 98
# Simulation Result (counts) : {'000': 132, '001': 115, '010': 123, '011': 145, '100': 107, '101': 142, '110': 141, '111': 95}
# ==================================================
#
# ==================================================
# Unitary Index : 9
# Name of Backend : ibm_nairobi
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 106
# Simulation Result (counts) : {'000': 180, '001': 102, '010': 121, '011': 128, '100': 97, '101': 128, '110': 124, '111': 120}
# ==================================================

# %%
ShorN35X16(shots=1000, backend_name="ibm_oslo", IsTwirl=False).SimulationQC()
# Out:
# ibmqfactory.load_account:WARNING:2023-04-06 06:10:12,637: Credentials are already in use. The existing account in the session will be replaced.
# 13
# 14
# ==================================================
# Name of Backend : ibm_oslo
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 104
# Simulation Result (counts) : {'000': 156, '001': 96, '010': 175, '011': 89, '100': 128, '101': 109, '110': 102, '111': 145}
# ==================================================

# %%
ShorN35X16(shots=1000, backend_name="ibm_oslo", IsTwirl=True).SimulationQC()
# Out:
# ibmqfactory.load_account:WARNING:2023-04-06 06:13:46,785: Credentials are already in use. The existing account in the session will be replaced.
# 13
# 14
# ==================================================
# Unitary Index : 1
# Name of Backend : ibm_oslo
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 95
# Simulation Result (counts) : {'000': 126, '001': 123, '010': 107, '011': 129, '100': 137, '101': 130, '110': 103, '111': 145}
# ==================================================
#
# ==================================================
# Unitary Index : 5
# Name of Backend : ibm_oslo
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 107
# Simulation Result (counts) : {'000': 139, '001': 132, '010': 155, '011': 106, '100': 113, '101': 97, '110': 144, '111': 114}
# ==================================================
#
# ==================================================
# Unitary Index : 9
# Name of Backend : ibm_oslo
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 104
# Simulation Result (counts) : {'000': 148, '001': 90, '010': 127, '011': 164, '100': 107, '101': 97, '110': 132, '111': 135}
# ==================================================

# %%
ShorN35X16(shots=1000, backend_name="ibmq_jakarta", IsTwirl=False).SimulationQC()
# Out:
# ibmqfactory.load_account:WARNING:2023-04-06 06:22:07,399: Credentials are already in use. The existing account in the session will be replaced.
# 8
# 14
# ==================================================
# Name of Backend : ibmq_jakarta
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 104
# Simulation Result (counts) : {'000': 163, '001': 116, '010': 125, '011': 178, '100': 109, '101': 84, '110': 141, '111': 84}
# ==================================================

# %%
ShorN35X16(shots=1000, backend_name="ibmq_jakarta", IsTwirl=True).SimulationQC()
# Out:
# ibmqfactory.load_account:WARNING:2023-04-06 14:32:11,984: Credentials are already in use. The existing account in the session will be replaced.
# 8
# 14
# ==================================================
# Unitary Index : 1
# Name of Backend : ibmq_jakarta
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 95
# Simulation Result (counts) : {'000': 159, '001': 150, '010': 123, '011': 91, '100': 133, '101': 141, '110': 101, '111': 102}
# ==================================================
#
# ==================================================
# Unitary Index : 5
# Name of Backend : ibmq_jakarta
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 98
# Simulation Result (counts) : {'000': 145, '001': 103, '010': 181, '011': 91, '100': 94, '101': 135, '110': 120, '111': 131}
# ==================================================
#
# ==================================================
# Unitary Index : 9
# Name of Backend : ibmq_jakarta
# Number of Total Shots : 1000
# Transpiled Quantum Circuit Depth : 100
# Simulation Result (counts) : {'000': 154, '001': 107, '010': 144, '011': 118, '100': 109, '101': 140, '110': 126, '111': 102}
# ==================================================
