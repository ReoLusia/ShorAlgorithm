# %% [markdown]
# ## Simulation of ShorN6X5

# %%
from qiskit.visualization import plot_histogram

ideal_result = {'0000': 0.5, '0001': 0, '0010': 0, '0011': 0, 
 '0100': 0, '0101': 0, '0110': 0, '0111': 0, 
 '1000': 0.5, '1001': 0, '1010': 0, '1011': 0, 
 '1100': 0, '1101': 0, '1110': 0, '1111': 0}

# %%
original_result_qas = {'0000': 0.523, '0001': 0, '0010': 0, '0011': 0, 
 '0100': 0, '0101': 0, '0110': 0, '0111': 0, 
 '1000': 0.477, '1001': 0, '1010': 0, '1011': 0, 
 '1100': 0, '1101': 0, '1110': 0, '1111': 0}

mitigated_result_qas = {'0000': 0.493, '0001': 0, '0010': 0, '0011': 0, 
 '0100': 0, '0101': 0, '0110': 0, '0111': 0, 
 '1000': 0.507, '1001': 0, '1010': 0, '1011': 0, 
 '1100': 0, '1101': 0, '1110': 0, '1111': 0}

title_qas = "ibmq_qasm simulator"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_qas, mitigated_result_qas], 
               legend=legend, bar_labels=False, title=title_qas)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_qas:
        temp += (ideal_result[x] - original_result_qas[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_qas:
        temp += (ideal_result[x] - mitigated_result_qas[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  6.612500000000012e-05
# With Mitigation :  6.125000000000011e-06

# %%
original_result_jak = {'0000': 0.065, '0001': 0.058, '0010': 0.048, '0011': 0.079, 
 '0100': 0.071, '0101': 0.054, '0110': 0.074, '0111': 0.067, 
 '1000': 0.062, '1001': 0.059, '1010': 0.055, '1011': 0.058, 
 '1100': 0.056, '1101': 0.075, '1110': 0.054, '1111': 0.065}

mitigated_result_jak = {'0000': 0.077, '0001': 0.071, '0010': 0.079, '0011': 0.065, 
 '0100': 0.089, '0101': 0.080, '0110': 0.062, '0111': 0.050, 
 '1000': 0.067, '1001': 0.069, '1010': 0.049, '1011': 0.037, 
 '1100': 0.050, '1101': 0.053, '1110': 0.054, '1111': 0.047}

title_jak = "ibmq_jakarta"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_jak, mitigated_result_jak], 
               legend=legend, bar_labels=False, title=title_jak)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_jak:
        temp += (ideal_result[x] - original_result_jak[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_jak:
        temp += (ideal_result[x] - mitigated_result_jak[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.027291999999999997
# With Mitigation :  0.026347187499999997

# %%
original_result_osl = {'0000': 0.081, '0001': 0.039, '0010': 0.043, '0011': 0.047, 
 '0100': 0.053, '0101': 0.049, '0110': 0.040, '0111': 0.027, 
 '1000': 0.059, '1001': 0.101, '1010': 0.051, '1011': 0.055, 
 '1100': 0.075, '1101': 0.076, '1110': 0.108, '1111': 0.096}

mitigated_result_osl = {'0000': 0.101, '0001': 0.089, '0010': 0.060, '0011': 0.049, 
 '0100': 0.047, '0101': 0.034, '0110': 0.040, '0111': 0.032, 
 '1000': 0.071, '1001': 0.061, '1010': 0.062, '1011': 0.061, 
 '1100': 0.071, '1101': 0.074, '1110': 0.077, '1111': 0.071}

title_osl = "ibmq_oslo"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_osl, mitigated_result_osl], 
               legend=legend, bar_labels=False, title=title_osl)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_osl:
        temp += (ideal_result[x] - original_result_osl[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_osl:
        temp += (ideal_result[x] - mitigated_result_osl[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.02695425
# With Mitigation :  0.024745374999999997

# %%
original_result_nai = {'0000': 0.060, '0001': 0.078, '0010': 0.069, '0011': 0.060, 
 '0100': 0.063, '0101': 0.078, '0110': 0.061, '0111': 0.048, 
 '1000': 0.086, '1001': 0.095, '1010': 0.073, '1011': 0.052, 
 '1100': 0.050, '1101': 0.055, '1110': 0.046, '1111': 0.026}

mitigated_result_nai = {'0000': 0.080, '0001': 0.063, '0010': 0.056, '0011': 0.051, 
 '0100': 0.084, '0101': 0.066, '0110': 0.063, '0111': 0.041, 
 '1000': 0.095, '1001': 0.066, '1010': 0.058, '1011': 0.049, 
 '1100': 0.067, '1101': 0.058, '1110': 0.061, '1111': 0.042}

title_nai = "ibmq_nairobi"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_nai, mitigated_result_nai], 
               legend=legend, bar_labels=False, title=title_nai)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_nai:
        temp += (ideal_result[x] - original_result_nai[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_nai:
        temp += (ideal_result[x] - mitigated_result_nai[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.026305875
# With Mitigation :  0.024415749999999996

# %%
original_result_lag = {'0000': 0.080, '0001': 0.071, '0010': 0.073, '0011': 0.082, 
 '0100': 0.068, '0101': 0.089, '0110': 0.065, '0111': 0.072, 
 '1000': 0.065, '1001': 0.052, '1010': 0.053, '1011': 0.051, 
 '1100': 0.039, '1101': 0.051, '1110': 0.038, '1111': 0.051}

mitigated_result_lag = {'0000': 0.070, '0001': 0.056, '0010': 0.077, '0011': 0.055, 
 '0100': 0.086, '0101': 0.067, '0110': 0.064, '0111': 0.060, 
 '1000': 0.069, '1001': 0.045, '1010': 0.060, '1011': 0.049, 
 '1100': 0.061, '1101': 0.061, '1110': 0.068, '1111': 0.055}

title_lag = "ibmq_lagos"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_lag, mitigated_result_lag], 
               legend=legend, bar_labels=False, title=title_lag)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_lag:
        temp += (ideal_result[x] - original_result_lag[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_lag:
        temp += (ideal_result[x] - mitigated_result_lag[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.026309625
# With Mitigation :  0.02659056249999999

# %%
original_result_per = {'0000': 0.075, '0001': 0.057, '0010': 0.051, '0011': 0.052, 
 '0100': 0.091, '0101': 0.056, '0110': 0.045, '0111': 0.067, 
 '1000': 0.092, '1001': 0.062, '1010': 0.069, '1011': 0.045, 
 '1100': 0.069, '1101': 0.062, '1110': 0.049, '1111': 0.058}

mitigated_result_per = {'0000': 0.057, '0001': 0.067, '0010': 0.062, '0011': 0.055, 
 '0100': 0.090, '0101': 0.065, '0110': 0.068, '0111': 0.062, 
 '1000': 0.072, '1001': 0.064, '1010': 0.072, '1011': 0.054, 
 '1100': 0.059, '1101': 0.050, '1110': 0.052, '1111': 0.051}

title_per = "ibmq_perth"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_per, mitigated_result_per], 
               legend=legend, bar_labels=False, title=title_per)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_per:
        temp += (ideal_result[x] - original_result_per[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_per:
        temp += (ideal_result[x] - mitigated_result_per[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.024910875000000002
# With Mitigation :  0.027191624999999997

# %%
original_result_gua = {'0000': 0.068, '0001': 0.047, '0010': 0.060, '0011': 0.073, 
 '0100': 0.072, '0101': 0.065, '0110': 0.070, '0111': 0.071, 
 '1000': 0.073, '1001': 0.071, '1010': 0.061, '1011': 0.068, 
 '1100': 0.045, '1101': 0.049, '1110': 0.050, '1111': 0.057}

mitigated_result_gua = {'0000': 0.074, '0001': 0.064, '0010': 0.072, '0011': 0.058, 
 '0100': 0.071, '0101': 0.067, '0110': 0.066, '0111': 0.056, 
 '1000': 0.078, '1001': 0.068, '1010': 0.058, '1011': 0.057, 
 '1100': 0.067, '1101': 0.059, '1110': 0.040, '1111': 0.045}

title_gua = "ibmq_guadalupe"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_gua, mitigated_result_gua], 
               legend=legend, bar_labels=False, title=title_gua)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_gua:
        temp += (ideal_result[x] - original_result_gua[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_gua:
        temp += (ideal_result[x] - mitigated_result_gua[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.026437624999999996
# With Mitigation :  0.025753625

# %%
original_result_tor = {'0000': 0.092, '0001': 0.078, '0010': 0.051, '0011': 0.044, 
 '0100': 0.089, '0101': 0.076, '0110': 0.069, '0111': 0.047, 
 '1000': 0.066, '1001': 0.057, '1010': 0.061, '1011': 0.043, 
 '1100': 0.066, '1101': 0.069, '1110': 0.048, '1111': 0.044}

mitigated_result_tor = {'0000': 0.057, '0001': 0.075, '0010': 0.061, '0011': 0.069, 
 '0100': 0.081, '0101': 0.078, '0110': 0.058, '0111': 0.069, 
 '1000': 0.077, '1001': 0.067, '1010': 0.055, '1011': 0.060, 
 '1100': 0.062, '1101': 0.044, '1110': 0.046, '1111': 0.043}

title_tor = "ibmq_toronto"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_tor, mitigated_result_tor], 
               legend=legend, bar_labels=False, title=title_tor)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_tor:
        temp += (ideal_result[x] - original_result_tor[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_tor:
        temp += (ideal_result[x] - mitigated_result_tor[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.02551775
# With Mitigation :  0.026932124999999998

# %%
original_result_gen = {'0000': 0.061, '0001': 0.078, '0010': 0.094, '0011': 0.076, 
 '0100': 0.070, '0101': 0.060, '0110': 0.075, '0111': 0.047, 
 '1000': 0.052, '1001': 0.057, '1010': 0.048, '1011': 0.071, 
 '1100': 0.034, '1101': 0.026, '1110': 0.069, '1111': 0.082}

mitigated_result_gen = {'0000': 0.069, '0001': 0.069, '0010': 0.056, '0011': 0.048, 
 '0100': 0.079, '0101': 0.072, '0110': 0.072, '0111': 0.074, 
 '1000': 0.062, '1001': 0.069, '1010': 0.064, '1011': 0.063, 
 '1100': 0.044, '1101': 0.052, '1110': 0.054, '1111': 0.054}

title_gen = "ibmq_geneva"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_gen, mitigated_result_gen], 
               legend=legend, bar_labels=False, title=title_gen)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_gen:
        temp += (ideal_result[x] - original_result_gen[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_gen:
        temp += (ideal_result[x] - mitigated_result_gen[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.028397875000000003
# With Mitigation :  0.027074312499999992

# %%
original_result_han = {'0000': 0.095, '0001': 0.080, '0010': 0.082, '0011': 0.074, 
 '0100': 0.050, '0101': 0.056, '0110': 0.061, '0111': 0.046, 
 '1000': 0.062, '1001': 0.075, '1010': 0.056, '1011': 0.085, 
 '1100': 0.048, '1101': 0.050, '1110': 0.039, '1111': 0.041}

mitigated_result_han = {'0000': 0.090, '0001': 0.083, '0010': 0.059, '0011': 0.060, 
 '0100': 0.069, '0101': 0.069, '0110': 0.052, '0111': 0.052, 
 '1000': 0.083, '1001': 0.063, '1010': 0.054, '1011': 0.054, 
 '1100': 0.054, '1101': 0.063, '1110': 0.054, '1111': 0.041}

title_han = "ibmq_hanoi"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_han, mitigated_result_han], 
               legend=legend, bar_labels=False, title=title_han)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_han:
        temp += (ideal_result[x] - original_result_han[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_han:
        temp += (ideal_result[x] - mitigated_result_han[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.025620874999999998
# With Mitigation :  0.024510749999999994

# %%
original_result_auc = {'0000': 0.056, '0001': 0.055, '0010': 0.048, '0011': 0.060, 
 '0100': 0.089, '0101': 0.049, '0110': 0.106, '0111': 0.051, 
 '1000': 0.064, '1001': 0.052, '1010': 0.065, '1011': 0.055, 
 '1100': 0.077, '1101': 0.049, '1110': 0.080, '1111': 0.044}

mitigated_result_auc = {'0000': 0.062, '0001': 0.046, '0010': 0.060, '0011': 0.051, 
 '0100': 0.071, '0101': 0.063, '0110': 0.067, '0111': 0.065, 
 '1000': 0.067, '1001': 0.055, '1010': 0.067, '1011': 0.047, 
 '1100': 0.069, '1101': 0.064, '1110': 0.084, '1111': 0.064}

title_auc = "ibmq_auckland"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_auc, mitigated_result_auc], 
               legend=legend, bar_labels=False, title=title_auc)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_auc:
        temp += (ideal_result[x] - original_result_auc[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_auc:
        temp += (ideal_result[x] - mitigated_result_auc[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.027933749999999997
# With Mitigation :  0.027194125

# %%
original_result_cai = {'0000': 0.050, '0001': 0.081, '0010': 0.054, '0011': 0.041, 
 '0100': 0.067, '0101': 0.073, '0110': 0.056, '0111': 0.053, 
 '1000': 0.060, '1001': 0.078, '1010': 0.061, '1011': 0.052, 
 '1100': 0.094, '1101': 0.086, '1110': 0.060, '1111': 0.034}

mitigated_result_cai = {'0000': 0.107, '0001': 0.067, '0010': 0.100, '0011': 0.093, 
 '0100': 0.118, '0101': 0.090, '0110': 0.045, '0111': 0.045, 
 '1000': 0.068, '1001': 0.068, '1010': 0.046, '1011': 0.042, 
 '1100': 0.036, '1101': 0.036, '1110': 0.021, '1111': 0.019}

title_cai = "ibmq_cairo"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_cai, mitigated_result_cai], 
               legend=legend, bar_labels=False, title=title_cai)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_cai:
        temp += (ideal_result[x] - original_result_cai[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_cai:
        temp += (ideal_result[x] - mitigated_result_cai[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.028532374999999995
# With Mitigation :  0.025136437500000004

# %%
original_result_mum = {'0000': 0.096, '0001': 0.044, '0010': 0.068, '0011': 0.068, 
 '0100': 0.071, '0101': 0.050, '0110': 0.075, '0111': 0.058, 
 '1000': 0.063, '1001': 0.065, '1010': 0.059, '1011': 0.048, 
 '1100': 0.067, '1101': 0.048, '1110': 0.065, '1111': 0.055}

mitigated_result_mum = {'0000': 0.078, '0001': 0.059, '0010': 0.049, '0011': 0.060, 
 '0100': 0.075, '0101': 0.060, '0110': 0.054, '0111': 0.055, 
 '1000': 0.065, '1001': 0.059, '1010': 0.060, '1011': 0.060, 
 '1100': 0.069, '1101': 0.065, '1110': 0.071, '1111': 0.061}

title_mum = "ibmq_mumbai"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_mum, mitigated_result_mum], 
               legend=legend, bar_labels=False, title=title_mum)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_mum:
        temp += (ideal_result[x] - original_result_mum[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_mum:
        temp += (ideal_result[x] - mitigated_result_mum[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.025371999999999995
# With Mitigation :  0.026274125

# %%
original_result_mon = {'0000': 0.073, '0001': 0.065, '0010': 0.070, '0011': 0.065, 
 '0100': 0.086, '0101': 0.076, '0110': 0.069, '0111': 0.057, 
 '1000': 0.066, '1001': 0.051, '1010': 0.057, '1011': 0.045, 
 '1100': 0.061, '1101': 0.065, '1110': 0.049, '1111': 0.045}

mitigated_result_mon = {'0000': 0.071, '0001': 0.079, '0010': 0.061, '0011': 0.050, 
 '0100': 0.061, '0101': 0.068, '0110': 0.064, '0111': 0.058, 
 '1000': 0.068, '1001': 0.054, '1010': 0.068, '1011': 0.062, 
 '1100': 0.061, '1101': 0.060, '1110': 0.063, '1111': 0.052}

title_mon = "ibmq_montreal"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_mon, mitigated_result_mon], 
               legend=legend, bar_labels=False, title=title_mon)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_mon:
        temp += (ideal_result[x] - original_result_mon[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_mon:
        temp += (ideal_result[x] - mitigated_result_mon[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.026591499999999994
# With Mitigation :  0.026519374999999994

# %%
original_result_kol = {'0000': 0.050, '0001': 0.057, '0010': 0.067, '0011': 0.053, 
 '0100': 0.053, '0101': 0.078, '0110': 0.084, '0111': 0.074, 
 '1000': 0.058, '1001': 0.040, '1010': 0.077, '1011': 0.067, 
 '1100': 0.054, '1101': 0.066, '1110': 0.054, '1111': 0.068}

mitigated_result_kol = {'0000': 0.068, '0001': 0.057, '0010': 0.086, '0011': 0.064, 
 '0100': 0.076, '0101': 0.074, '0110': 0.053, '0111': 0.049, 
 '1000': 0.048, '1001': 0.063, '1010': 0.055, '1011': 0.050, 
 '1100': 0.067, '1101': 0.077, '1110': 0.061, '1111': 0.054}

title_kol = "ibmq_kolkata"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_kol, mitigated_result_kol], 
               legend=legend, bar_labels=False, title=title_kol)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_kol:
        temp += (ideal_result[x] - original_result_kol[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_kol:
        temp += (ideal_result[x] - mitigated_result_kol[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.028541625000000004
# With Mitigation :  0.0280425

# %%
original_result_she = {'0000': 0.086, '0001': 0.066, '0010': 0.042, '0011': 0.030, 
 '0100': 0.078, '0101': 0.073, '0110': 0.091, '0111': 0.079, 
 '1000': 0.071, '1001': 0.054, '1010': 0.020, '1011': 0.015, 
 '1100': 0.053, '1101': 0.069, '1110': 0.098, '1111': 0.075}

mitigated_result_she = {'0000': 0.071, '0001': 0.072, '0010': 0.025, '0011': 0.023, 
 '0100': 0.073, '0101': 0.058, '0110': 0.072, '0111': 0.062, 
 '1000': 0.081, '1001': 0.083, '1010': 0.028, '1011': 0.033, 
 '1100': 0.079, '1101': 0.081, '1110': 0.073, '1111': 0.087}

title_she = "ibmq_sherbrooke"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_she, mitigated_result_she], 
               legend=legend, bar_labels=False, title=title_she)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_she:
        temp += (ideal_result[x] - original_result_she[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_she:
        temp += (ideal_result[x] - mitigated_result_she[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.02592075
# With Mitigation :  0.02613268749999999

# %%
original_result_was = {'0000': 0.065, '0001': 0.060, '0010': 0.078, '0011': 0.050, 
 '0100': 0.064, '0101': 0.066, '0110': 0.070, '0111': 0.052, 
 '1000': 0.059, '1001': 0.046, '1010': 0.064, '1011': 0.029, 
 '1100': 0.088, '1101': 0.071, '1110': 0.080, '1111': 0.058}

mitigated_result_was = {'0000': 0.064, '0001': 0.066, '0010': 0.077, '0011': 0.070, 
 '0100': 0.064, '0101': 0.060, '0110': 0.061, '0111': 0.050, 
 '1000': 0.075, '1001': 0.057, '1010': 0.060, '1011': 0.061, 
 '1100': 0.057, '1101': 0.059, '1110': 0.055, '1111': 0.064}

title_was = "ibmq_washington"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_was, mitigated_result_was], 
               legend=legend, bar_labels=False, title=title_was)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_was:
        temp += (ideal_result[x] - original_result_was[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_was:
        temp += (ideal_result[x] - mitigated_result_was[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.02759675
# With Mitigation :  0.026515249999999994

# %% [markdown]
# ## Simulation of ShorN21X4

# %%
ideal_result = {'000': 0.406, '001': 0.037, '010': 0.031, '011': 0.213, 
                '100': 0.031, '101': 0.213, '110': 0.031, '111': 0.037}

# %%
original_result_qas = {'000': 0.373, '001': 0.019, '010': 0.056, '011': 0.204, 
                       '100': 0.034, '101': 0.234, '110': 0.061, '111': 0.019}

mitigated_result_qas = {'000': 0.351, '001': 0.016, '010': 0.051, '011': 0.243, 
                       '100': 0.025, '101': 0.240, '110': 0.059, '111': 0.014}

title_qas = "ibmq_qasm simulator"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_qas, mitigated_result_qas], 
               legend=legend, bar_labels=False, title=title_qas)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_qas:
        temp += (ideal_result[x] - original_result_qas[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_qas:
        temp += (ideal_result[x] - mitigated_result_qas[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.0004741250000000004
# With Mitigation :  0.0008555000000000006

# %%
original_result_jak = {'000': 0.133, '001': 0.155, '010': 0.115, '011': 0.132, 
                       '100': 0.135, '101': 0.086, '110': 0.141, '111': 0.103}

mitigated_result_jak = {'000': 0.141, '001': 0.112, '010': 0.134, '011': 0.126, 
                       '100': 0.108, '101': 0.124, '110': 0.128, '111': 0.127}

title_jak = "ibmq_jakarta"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_jak, mitigated_result_jak], 
               legend=legend, bar_labels=False, title=title_jak)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_jak:
        temp += (ideal_result[x] - original_result_jak[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_jak:
        temp += (ideal_result[x] - mitigated_result_jak[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.018183875000000002
# With Mitigation :  0.015673375000000003

# %%
original_result_osl = {'000': 0.112, '001': 0.112, '010': 0.132, '011': 0.090, 
                       '100': 0.146, '101': 0.105, '110': 0.147, '111': 0.156}

mitigated_result_osl = {'000': 0.156, '001': 0.094, '010': 0.141, '011': 0.109, 
                       '100': 0.117, '101': 0.117, '110': 0.133, '111': 0.133}

title_osl = "ibmq_oslo"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_osl, mitigated_result_osl], 
               legend=legend, bar_labels=False, title=title_osl)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_osl:
        temp += (ideal_result[x] - original_result_osl[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_osl:
        temp += (ideal_result[x] - mitigated_result_osl[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.021237125000000006
# With Mitigation :  0.015612125

# %%
original_result_nai = {'000': 0.154, '001': 0.121, '010': 0.094, '011': 0.128, 
                       '100': 0.101, '101': 0.142, '110': 0.128, '111': 0.132}

mitigated_result_nai = {'000': 0.131, '001': 0.129, '010': 0.139, '011': 0.105, 
                       '100': 0.132, '101': 0.111, '110': 0.130, '111': 0.124}

title_nai = "ibmq_nairobi"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_nai, mitigated_result_nai], 
               legend=legend, bar_labels=False, title=title_nai)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_nai:
        temp += (ideal_result[x] - original_result_nai[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_nai:
        temp += (ideal_result[x] - mitigated_result_nai[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.013766125
# With Mitigation :  0.018174000000000003

# %%
original_result_lag = {'000': 0.110, '001': 0.120, '010': 0.129, '011': 0.111, 
                       '100': 0.134, '101': 0.146, '110': 0.130, '111': 0.120}

mitigated_result_lag = {'000': 0.124, '001': 0.108, '010': 0.124, '011': 0.131, 
                       '100': 0.138, '101': 0.149, '110': 0.107, '111': 0.118}

title_lag = "ibmq_lagos"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_lag, mitigated_result_lag], 
               legend=legend, bar_labels=False, title=title_lag)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_lag:
        temp += (ideal_result[x] - original_result_lag[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_lag:
        temp += (ideal_result[x] - mitigated_result_lag[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.018287625000000002
# With Mitigation :  0.015977500000000002

# %%
original_result_per = {'000': 0.116, '001': 0.114, '010': 0.134, '011': 0.128, 
                       '100': 0.115, '101': 0.132, '110': 0.134, '111': 0.127}

mitigated_result_per = {'000': 0.131, '001': 0.123, '010': 0.118, '011': 0.127, 
                       '100': 0.127, '101': 0.129, '110': 0.128, '111': 0.117}

title_per = "ibmq_perth"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_per, mitigated_result_per], 
               legend=legend, bar_labels=False, title=title_per)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_per:
        temp += (ideal_result[x] - original_result_per[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_per:
        temp += (ideal_result[x] - mitigated_result_per[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.017523625000000004
# With Mitigation :  0.016258375

# %%
original_result_gua = {'000': 0.148, '001': 0.136, '010': 0.140, '011': 0.122, 
                       '100': 0.117, '101': 0.095, '110': 0.159, '111': 0.083}

mitigated_result_gua = {'000': 0.158, '001': 0.108, '010': 0.144, '011': 0.104, 
                       '100': 0.121, '101': 0.114, '110': 0.154, '111': 0.098}

title_gua = "ibmq_guadalupe"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_gua, mitigated_result_gua], 
               legend=legend, bar_labels=False, title=title_gua)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_gua:
        temp += (ideal_result[x] - original_result_gua[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_gua:
        temp += (ideal_result[x] - mitigated_result_gua[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.017043375000000003
# With Mitigation :  0.01599325

# %%
original_result_tor = {'000': 0.151, '001': 0.134, '010': 0.120, '011': 0.153, 
                       '100': 0.107, '101': 0.103, '110': 0.143, '111': 0.089}

mitigated_result_tor = {'000': 0.132, '001': 0.132, '010': 0.116, '011': 0.136, 
                       '100': 0.131, '101': 0.119, '110': 0.122, '111': 0.112}

title_tor = "ibmq_toronto"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_tor, mitigated_result_tor], 
               legend=legend, bar_labels=False, title=title_tor)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_tor:
        temp += (ideal_result[x] - original_result_tor[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_tor:
        temp += (ideal_result[x] - mitigated_result_tor[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.014884875
# With Mitigation :  0.016249625

# %%
original_result_gen = {'000': 0.139, '001': 0.130, '010': 0.121, '011': 0.098, 
                       '100': 0.151, '101': 0.090, '110': 0.137, '111': 0.134}

mitigated_result_gen = {'000': 0.116, '001': 0.123, '010': 0.123, '011': 0.102, 
                       '100': 0.129, '101': 0.139, '110': 0.138, '111': 0.131}

title_gen = "ibmq_geneva"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_gen, mitigated_result_gen], 
               legend=legend, bar_labels=False, title=title_gen)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_gen:
        temp += (ideal_result[x] - original_result_gen[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_gen:
        temp += (ideal_result[x] - mitigated_result_gen[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.018929625
# With Mitigation :  0.018455750000000007

# %%
original_result_han = {'000': 0.160, '001': 0.094, '010': 0.119, '011': 0.159, 
                       '100': 0.103, '101': 0.102, '110': 0.140, '111': 0.123}

mitigated_result_han = {'000': 0.125, '001': 0.090, '010': 0.192, '011': 0.103, 
                       '100': 0.105, '101': 0.108, '110': 0.133, '111': 0.145}

title_han = "ibmq_hanoi"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_han, mitigated_result_han], 
               legend=legend, bar_labels=False, title=title_han)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_han:
        temp += (ideal_result[x] - original_result_han[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_han:
        temp += (ideal_result[x] - mitigated_result_han[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.013900875000000002
# With Mitigation :  0.019795000000000004

# %%
original_result_auc = {'000': 0.160, '001': 0.080, '010': 0.137, '011': 0.100, 
                       '100': 0.111, '101': 0.080, '110': 0.189, '111': 0.143}

mitigated_result_auc = {'000': 0.151, '001': 0.102, '010': 0.117, '011': 0.123, 
                       '100': 0.119, '101': 0.113, '110': 0.155, '111': 0.121}

title_auc = "ibmq_auckland"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_auc, mitigated_result_auc], 
               legend=legend, bar_labels=False, title=title_auc)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_auc:
        temp += (ideal_result[x] - original_result_auc[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_auc:
        temp += (ideal_result[x] - mitigated_result_auc[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.018332375
# With Mitigation :  0.015615249999999999

# %%
original_result_cai = {'000': 0.144, '001': 0.114, '010': 0.156, '011': 0.141, 
                       '100': 0.107, '101': 0.129, '110': 0.097, '111': 0.112}

mitigated_result_cai = {'000': 0.138, '001': 0.109, '010': 0.128, '011': 0.134, 
                       '100': 0.110, '101': 0.103, '110': 0.151, '111': 0.127}

title_cai = "ibmq_cairo"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_cai, mitigated_result_cai], 
               legend=legend, bar_labels=False, title=title_cai)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_cai:
        temp += (ideal_result[x] - original_result_cai[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_cai:
        temp += (ideal_result[x] - mitigated_result_cai[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.014774375000000003
# With Mitigation :  0.016687375

# %%
original_result_mum = {'000': 0.148, '001': 0.130, '010': 0.106, '011': 0.135, 
                       '100': 0.121, '101': 0.146, '110': 0.114, '111': 0.100}

mitigated_result_mum = {'000': 0.143, '001': 0.131, '010': 0.134, '011': 0.144, 
                       '100': 0.115, '101': 0.111, '110': 0.131, '111': 0.092}

title_mum = "ibmq_mumbai"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_mum, mitigated_result_mum], 
               legend=legend, bar_labels=False, title=title_mum)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_mum:
        temp += (ideal_result[x] - original_result_mum[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_mum:
        temp += (ideal_result[x] - mitigated_result_mum[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.013796125000000001
# With Mitigation :  0.015482500000000003

# %%
original_result_mon = {'000': 0.135, '001': 0.143, '010': 0.111, '011': 0.150, 
                       '100': 0.104, '101': 0.096, '110': 0.164, '111': 0.097}

mitigated_result_mon = {'000': 0.163, '001': 0.110, '010': 0.127, '011': 0.137, 
                       '100': 0.103, '101': 0.135, '110': 0.112, '111': 0.116}

title_mon = "ibmq_montreal"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_mon, mitigated_result_mon], 
               legend=legend, bar_labels=False, title=title_mon)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_mon:
        temp += (ideal_result[x] - original_result_mon[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_mon:
        temp += (ideal_result[x] - mitigated_result_mon[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.016919125
# With Mitigation :  0.01293

# %%
original_result_kol = {'000': 0.125, '001': 0.136, '010': 0.116, '011': 0.143, 
                       '100': 0.140, '101': 0.078, '110': 0.145, '111': 0.117}

mitigated_result_kol = {'000': 0.130, '001': 0.113, '010': 0.135, '011': 0.121, 
                       '100': 0.128, '101': 0.119, '110': 0.151, '111': 0.105}

title_kol = "ibmq_kolkata"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_kol, mitigated_result_kol], 
               legend=legend, bar_labels=False, title=title_kol)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_kol:
        temp += (ideal_result[x] - original_result_kol[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_kol:
        temp += (ideal_result[x] - mitigated_result_kol[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.018798625000000006
# With Mitigation :  0.017312625

# %%
original_result_she = {'000': 0.055, '001': 0.233, '010': 0.109, '011': 0.142, 
                       '100': 0.081, '101': 0.084, '110': 0.096, '111': 0.200}

mitigated_result_she = {'000': 0.157, '001': 0.139, '010': 0.103, '011': 0.149, 
                       '100': 0.110, '101': 0.151, '110': 0.108, '111': 0.082}

title_she = "ibmq_sherbrooke"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_she, mitigated_result_she], 
               legend=legend, bar_labels=False, title=title_she)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_she:
        temp += (ideal_result[x] - original_result_she[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_she:
        temp += (ideal_result[x] - mitigated_result_she[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.027834625
# With Mitigation :  0.012465500000000001

# %%
original_result_was = {'000': 0.137, '001': 0.123, '010': 0.132, '011': 0.199, 
                       '100': 0.093, '101': 0.064, '110': 0.170, '111': 0.082}

mitigated_result_was = {'000': 0.101, '001': 0.103, '010': 0.135, '011': 0.182, 
                       '100': 0.085, '101': 0.100, '110': 0.191, '111': 0.102}

title_was = "ibmq_washington"
legend = ["Ideal", "Without Mitigation", "With Mitigation"]
plot_histogram([ideal_result, original_result_was, mitigated_result_was], 
               legend=legend, bar_labels=False, title=title_was)

# %%
temp = 0
for x in ideal_result:
    if x in original_result_was:
        temp += (ideal_result[x] - original_result_was[x])**2
print("Without Mitigation : ", temp/len(ideal_result))

temp = 0
for x in ideal_result:
    if x in mitigated_result_was:
        temp += (ideal_result[x] - mitigated_result_was[x])**2
print("With Mitigation : ", temp/len(ideal_result))
# Out:
# Without Mitigation :  0.017193125000000004
# With Mitigation :  0.019333500000000007
